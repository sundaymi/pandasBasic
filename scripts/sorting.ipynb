# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
df.sort_values(by='Country')  # inplace=True to keep the changes
# Out:
#        ResponseId                                         MainBranch  \
# 37431       37432             I am a student who is learning to code
# 11461       11462                     I am a developer by profession
# 67130       67131                     I am a developer by profession
# 62970       62971  I am not primarily a developer, but I write co...
# 14882       14883                     I am a developer by profession
# ...           ...                                                ...
# 13194       13195                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
# 73741       73742                     I am a developer by profession
# 73192       73193                     I am a developer by profession
# 38428       38429                     I am a developer by profession
#
#                                    Employment      Country US_State  \
# 37431                      Student, part-time  Afghanistan      NaN
# ...

# %%
df['Country'].head(50)  # it gives us the first 50 countries sorted
# Out:
# 0                                              Slovakia
# 1                                           Netherlands
# 2                                    Russian Federation
# 3                                               Austria
# 4     United Kingdom of Great Britain and Northern I...
# 5                              United States of America
# 6                              United States of America
# 7                                              Malaysia
# 8                                                 India
# 9                                                Sweden
# 10    United Kingdom of Great Britain and Northern I...
# 11                                                Spain
# 12                                              Germany
# 13                                                 Peru
# 14    United Kingdom of Great Britain and Northern I...
# 15                             United States of America
# 16                                               Turkey
# ...

# %%
#df[['Country', 'ConvertedComp']].head(50)
# it gives us the first 50 countries sorted and their salaries

# %%
#df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=False)
# here we print country and salaries byt salaries are descending

# %%
#df['ConvertedComp'].nlargest(10)
# here we want to see the ten highest salaries of the survey

# %%
#df.nlargest(10, 'ConvertedComp')
# it will show us all the survey results instead of the previous example with only one column(or more)
# the opposite method is .nsmallest()
