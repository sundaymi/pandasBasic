# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
filt = (df['Country'] == 'Greece')

# %%
gr_df = df.loc[filt]

# %%
gr_df
# Out:
#        ResponseId                                         MainBranch  \
# 50             51                     I am a developer by profession
# 112           113                        I code primarily as a hobby
# 179           180                     I am a developer by profession
# 208           209                     I am a developer by profession
# 366           367                     I am a developer by profession
# ...           ...                                                ...
# 82734       82735             I am a student who is learning to code
# 82769       82770                     I am a developer by profession
# 82820       82821  I am not primarily a developer, but I write co...
# 83017       83018                     I am a developer by profession
# 83116       83117                     I am a developer by profession
#
#                 Employment Country US_State UK_Country  \
# 50      Employed full-time  Greece      NaN        NaN
# ...

# %%
# gr_df.to_csv('greece.csv')
# gr_df.to_csv('greece.tsv', sep='\t')  # it's like csv but with tabs

# %%
# to do this you have to install xlwt openpyxl xlrd
# gr_df.to_excel('greece.xlsx')  # it takes some time to make this

# %%
# test = pd.read_excel('greece.xlsx', index_col='Respondent')

# %%
# gr_df.to_json('greece.json')
# gr_df.to_json('greece.json', orient='records', lines=True)
# test = pd.read_json('greece.json', orient='records', lines=True)

# %%
# for databases, you install SQLAlchemy psycopg2-binary
# from SQLAlchemy import create_engine
# import psycopg2
# engine = create_engine('postgresql://<username>:<password>@localhost:port/<db_filename>')
# gr_df.to_sql('sample table', engine, if_exists='replace')
# for if_exists you can set it as you want, check documentation
# sql_df = pd.read_sql('sample table', engine, index_col='Respondent')
# sql_df.head()
# sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')
# sql_df.head()
